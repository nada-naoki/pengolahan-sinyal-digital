# %%
import imageio
import matplotlib.pyplot as plt

# Load the hand radiograph
im = (imageio.imread('mri.JPG'))
# Plot the grayscale image
plt.imshow(im, cmap='gray')
plt.title("Original Image")
plt.axis('off')
plt.show()
# Out:
# C:\Users\Aldo Pranata\AppData\Local\Temp\ipykernel_23732\380719955.py:5: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   im = (imageio.imread('mri.JPG'))

# %%
import scipy.ndimage as ndi
filt_median = ndi.median_filter(im, size=5)

plt.imshow(filt_median, cmap='gray')
plt.title("Filtered Image Median")
plt.axis('off')
plt.show()
